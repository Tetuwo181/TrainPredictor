# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
from google.colab import drive
drive.mount('/content/drive')
# !mkdir -p drive
# !cd drive
# !ls drive

# %%
import os
os.chdir('/content/drive/My Drive/colab/TrainPredictor')

# %%
from DataIO import data_loader
from network_model import cross_validator 
from network_model import model_builder as mb
IMG_DIR = "dataSet"
IMG_COLOR = "RGB"
IMG_SIZE = 32
channel = 3 if IMG_COLOR == "RGB" else 1
MODEL_NAME = "simple_cnn"
kernel_size = (3,3)
fold_num = 10
epoch_num = 1000

# %%
data_set, label_set, class_names, class_num = data_loader.load_dataset(IMG_DIR, 2, IMG_SIZE, IMG_COLOR)
len(data_set)

# %% [markdown]
# # TensorBoardのための準備

# %%
! npm i -g npm to update 
! npm install -g localtunnel
# Out:
# /tools/node/bin/npm -> /tools/node/lib/node_modules/npm/bin/npm-cli.js
# /tools/node/bin/npx -> /tools/node/lib/node_modules/npm/bin/npx-cli.js
# /tools/node/bin/update -> /tools/node/lib/node_modules/update/bin/update.js
# + npm@6.9.0
# + to@0.2.9
# + update@0.7.4
# updated 3 packages in 9.672s
# /tools/node/bin/lt -> /tools/node/lib/node_modules/localtunnel/bin/client
# + localtunnel@1.9.1
# updated 1 package in 1.304s

# %%
get_ipython().system_raw(
    'tensorboard --logdir {} --host 0.0.0.0 --port 6006 &'
    .format(os.path.join(os.getcwd(), "tflog"))
)
get_ipython().system_raw('lt --port 6006 >> url.txt 2>&1 &')

# %%
# !cat url.txt

# %% [markdown]
# # 交差検証を行い, 実際にコードを回す

# %%
model_generator = mb.build_wrapper(IMG_SIZE, channel, kernel_size, MODEL_NAME)
cross_validation = cross_validator.build(model_generator, class_names, os.path.join(os.getcwd(), "result"), fold_num, epoch_num)
cross_validation(data_set, label_set, MODEL_NAME, MODEL_NAME)

# %%
print(data_set[0][0][0])
print(label_set[-1])
print(channel)
